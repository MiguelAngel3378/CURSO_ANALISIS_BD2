# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import folium

# %%
url = 'https://restcountries.com/v3.1/all'
data = pd.read_json(url)

df = pd.DataFrame(data)

m = folium.Map(location=[20, 0], zoom_start=2)

for i in range(10):
    lat = df.iloc[i]['latlng'][0]
    lon = df.iloc[i]['latlng'][1]
    name = df.iloc[i]['name']['common']
    folium.Marker([lat, lon], popup=name).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6dc285c8d7008c9d7c3466c3e350438e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6dc285c8d7008c9d7c3466c3e350438e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6dc285c8d7008c9d7c3466c3e350438e = L.map(
#                 &quot;map_6dc285c8d7008c9d7c3466c3e350438e&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1ce8920ec432928130a07baadf514c0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6dc285c8d7008c9d7c3466c3e350438e);
#
#
#             var marker_6adff8f25b8f4051c70307d612d02c60 = L.marker(
#                 [31.0, 36.0],
#                 {}
#             ).addTo(map_6dc285c8d7008c9d7c3466c3e350438e);
#
#
#         var popup_56643e45d86308bba79d5f3510f7c6a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_183d3827036936eeeada2751f974f808 = $(`&lt;div id=&quot;html_183d3827036936eeeada2751f974f808&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jordan&lt;/div&gt;`)[0];
#                 popup_56643e45d86308bba79d5f3510f7c6a4.setContent(html_183d3827036936eeeada2751f974f808);
#
#
#
#         marker_6adff8f25b8f4051c70307d612d02c60.bindPopup(popup_56643e45d86308bba79d5f3510f7c6a4)
#         ;
#
#
#
#
#             var marker_499204f7e3eff280960679065db2de8a = L.marker(
#                 [15.2, 145.75],
#                 {}
#             ).addTo(map_6dc285c8d7008c9d7c3466c3e350438e);
#
#
#         var popup_2d0c4b70de677c5ccf4383278de9ba89 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a89151b8d9fc7539c624d9baae7e24f7 = $(`&lt;div id=&quot;html_a89151b8d9fc7539c624d9baae7e24f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Northern Mariana Islands&lt;/div&gt;`)[0];
#                 popup_2d0c4b70de677c5ccf4383278de9ba89.setContent(html_a89151b8d9fc7539c624d9baae7e24f7);
#
#
#
#         marker_499204f7e3eff280960679065db2de8a.bindPopup(popup_2d0c4b70de677c5ccf4383278de9ba89)
#         ;
#
#
#
#
#             var marker_cb820d30d6626d89bbbe76efb0847a52 = L.marker(
#                 [44.0, 21.0],
#                 {}
#             ).addTo(map_6dc285c8d7008c9d7c3466c3e350438e);
#
#
#         var popup_bfd680cd497530bdef89ef58f3468d40 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cc6e3d0a8f74cced480574495b44f4f8 = $(`&lt;div id=&quot;html_cc6e3d0a8f74cced480574495b44f4f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Serbia&lt;/div&gt;`)[0];
#                 popup_bfd680cd497530bdef89ef58f3468d40.setContent(html_cc6e3d0a8f74cced480574495b44f4f8);
#
#
#
#         marker_cb820d30d6626d89bbbe76efb0847a52.bindPopup(popup_bfd680cd497530bdef89ef58f3468d40)
#         ;
#
#
#
#
#             var marker_59b74b0864ad6c1cc83631015772b5e8 = L.marker(
#                 [42.5, 1.5],
#                 {}
#             ).addTo(map_6dc285c8d7008c9d7c3466c3e350438e);
#
#
#         var popup_848fec3022633c2f6efeebc1bf7885b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_392b3b1d08131035113b2f022000d69b = $(`&lt;div id=&quot;html_392b3b1d08131035113b2f022000d69b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Andorra&lt;/div&gt;`)[0];
#                 popup_848fec3022633c2f6efeebc1bf7885b4.setContent(html_392b3b1d08131035113b2f022000d69b);
#
#
#
#         marker_59b74b0864ad6c1cc83631015772b5e8.bindPopup(popup_848fec3022633c2f6efeebc1bf7885b4)
#         ;
#
#
#
#
#             var marker_dade9f717c2a9c5d264e66aba7f8f3d0 = L.marker(
#                 [21.75, -71.58333333],
#                 {}
#             ).addTo(map_6dc285c8d7008c9d7c3466c3e350438e);
#
#
#         var popup_1a320eefc8de91390faf2e34699a6752 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ebd8c5aa5f0b317268e3b01c682ff24a = $(`&lt;div id=&quot;html_ebd8c5aa5f0b317268e3b01c682ff24a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Turks and Caicos Islands&lt;/div&gt;`)[0];
#                 popup_1a320eefc8de91390faf2e34699a6752.setContent(html_ebd8c5aa5f0b317268e3b01c682ff24a);
#
#
#
#         marker_dade9f717c2a9c5d264e66aba7f8f3d0.bindPopup(popup_1a320eefc8de91390faf2e34699a6752)
#         ;
#
#
#
#
#             var marker_bff1a1c3f9320fec8cf0a2a60f0f1c5d = L.marker(
#                 [32.33333333, -64.75],
#                 {}
#             ).addTo(map_6dc285c8d7008c9d7c3466c3
