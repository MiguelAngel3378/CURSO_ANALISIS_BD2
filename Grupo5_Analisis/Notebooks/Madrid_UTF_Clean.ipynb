# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('../../Grupo5_Analisis/Data/MADRID_UTF8_CLEAN.csv')
df.head(10)
# Out:
#    municipio_codigo municipio_nombre  distrito_codigo distrito_nombre  \
# 0                79           Madrid            79601          Centro
# 1                79           Madrid            79601          Centro
# 2                79           Madrid            79601          Centro
# 3                79           Madrid            79601          Centro
# 4                79           Madrid            79601          Centro
# 5                79           Madrid            79601          Centro
# 6                79           Madrid            79601          Centro
# 7                79           Madrid            79601          Centro
# 8                79           Madrid            79601          Centro
# 9                79           Madrid            79601          Centro
#
#    barrio_codigo barrio_nombre    sexo                  nacionalidad  \
# 0         796011       Palacio  Hombre                        Africa
# ...

# %%
df.head(50)
# Out:
#     municipio_codigo municipio_nombre  distrito_codigo distrito_nombre  \
# 0                 79           Madrid            79601          Centro
# 1                 79           Madrid            79601          Centro
# 2                 79           Madrid            79601          Centro
# 3                 79           Madrid            79601          Centro
# 4                 79           Madrid            79601          Centro
# 5                 79           Madrid            79601          Centro
# 6                 79           Madrid            79601          Centro
# 7                 79           Madrid            79601          Centro
# 8                 79           Madrid            79601          Centro
# 9                 79           Madrid            79601          Centro
# 10                79           Madrid            79601          Centro
# 11                79           Madrid            79601          Centro
# ...

# %%
df.tail()
# Out:
#       municipio_codigo municipio_nombre  distrito_codigo distrito_nombre  \
# 2555                79           Madrid            79621         Barajas
# 2556                79           Madrid            79621         Barajas
# 2557                79           Madrid            79621         Barajas
# 2558                79           Madrid            79621         Barajas
# 2559                79           Madrid            79621         Barajas
#
#       barrio_codigo barrio_nombre   sexo             nacionalidad  \
# 2555         796215    Corralejos  Mujer                     Asia
# 2556         796215    Corralejos  Mujer                  Oceanía
# 2557         796215    Corralejos  Mujer  Otros países de América
# 2558         796215    Corralejos  Mujer          Resto de Europa
# 2559         796215    Corralejos  Mujer            Unión Europea
#
#       poblacion_empadronada
# 2555                     14
# 2556                      0
# 2557                      0
# ...

# %%
df.describe(include='all')
# Out:
#         municipio_codigo municipio_nombre  distrito_codigo distrito_nombre  \
# count             2560.0             2560      2560.000000            2560
# unique               NaN                1              NaN              21
# top                  NaN           Madrid              NaN   Ciudad Lineal
# freq                 NaN             2560              NaN             180
# mean                79.0              NaN     79610.507812             NaN
# std                  0.0              NaN         5.807914             NaN
# min                 79.0              NaN     79601.000000             NaN
# 25%                 79.0              NaN     79606.000000             NaN
# 50%                 79.0              NaN     79610.000000             NaN
# 75%                 79.0              NaN     79615.000000             NaN
# max                 79.0              NaN     79621.000000             NaN
#
#         barrio_codigo barrio_nombre    sexo nacionalidad  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2560 entries, 0 to 2559
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   municipio_codigo       2560 non-null   int64
#  1   municipio_nombre       2560 non-null   object
#  2   distrito_codigo        2560 non-null   int64
#  3   distrito_nombre        2560 non-null   object
#  4   barrio_codigo          2560 non-null   int64
#  5   barrio_nombre          2560 non-null   object
#  6   sexo                   2560 non-null   object
#  7   nacionalidad           2560 non-null   object
#  8   poblacion_empadronada  2560 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 180.1+ KB

# %%
df.isnull().sum()
# Out:
# municipio_codigo         0
# municipio_nombre         0
# distrito_codigo          0
# distrito_nombre          0
# barrio_codigo            0
# barrio_nombre            0
# sexo                     0
# nacionalidad             0
# poblacion_empadronada    0
# dtype: int64

# %%
sns.pairplot(df)

# %%
sns.scatterplot(data=df, x='sexo', y='nacionalidad', hue='barrio_codigo')
# Out:
# <Axes: xlabel='sexo', ylabel='nacionalidad'>

# %%
df_corr = df.corr(numeric_only=True).round(2)
sns.heatmap(df_corr, cmap='viridis', annot=True);

# %%
filter = df['smoker'] =='no'
df_non_smooker = df[filter]
df_corr = df.corr(numeric_only=True).round(2)
sns.heatmap(df_corr, cmap='viridis', annot=True);
